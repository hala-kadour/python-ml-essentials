# %% [markdown]
# # Advanced Functional Tools in Python
#
# Python provides powerful functional tools to write cleaner, more efficient, and reusable code.
#
# In this notebook, we will cover:
# 1. **Partial Functions** (`functools.partial`) to pre-fill argument values.
# 2. **Generators** and `yield` for memory-efficient iteration.
# 3. Function **Decorators** to extend function behavior cleanly.
# 4. Applying functions to data structures using **`map()`** and **Pandas `.apply()`**.
